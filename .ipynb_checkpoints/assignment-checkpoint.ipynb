# %%
import sys
sys.path.append("..")

# %%
import pandas as pd
import random
from src.simulation import simulate

# %%
assortment_df = pd.read_csv("data/assortment.csv",
                            dtype={"product_id": str,
                                   "product_group": str,
                                   })

orders_df = pd.read_csv("data/orders.csv",
                        parse_dates=['datetime'])

# %% [markdown]
# ### Assortment
# Each row in 'assortment_df' contains a product that we have in our assortment that could be ordered.
#
# Column definitions:
# * product_id: product identifier
# * product_group: lower-level category of product
# * size_group: size of the product
# * cluster: higher-level category of product
#
# ### Orders
# Each row in 'orders_df' contains an shop order line.
#
# Column definitions:
# * datetime: datetime when the shop order is placed
# * order_id: order identifier
# * product_id: product that is ordered

# %%
def generate_naive_stock_allocation(assortment):
    warehouse_allocations = random.choices([[True, True],[True, False], [False, True]],
                              k=len(assortment), weights=[0.1, 0.45, 0.45])

    return pd.concat([assortment['product_id'], pd.DataFrame(warehouse_allocations, columns=[
        'warehouseA', 'warehouseB'])], axis=1)

# %%
stock_allocation = generate_naive_stock_allocation(assortment_df)
stock_allocation.head()
# Out:
#         product_id  warehouseA  warehouseB
# 0  007e97352fdb433        True       False
# 1  32b8b71245fc430        True       False
# 2  d6825ec8a7d5409       False        True
# 3  93210367755d441        True        True
# 4  1302c851692140a       False        True

# %%
simulation_result = simulate(orders_df, stock_allocation)
simulation_result.show_aggregated_results()
# Out:
# Warehouse orders sourced: 121578
# Total costs: 897498.1
# Lost sales: 8906 products

# %%
simulation_result.warehouse_orders
# Out:
#        shop_order_id warehouse_id    pack_line  \
# 0       00330b8e0df6   warehouseB   monoManual
# 1       0349de8a0eb0   warehouseA   monoManual
# 2       0349de8a0eb0   warehouseB  multiManual
# 3       051f784d56df   warehouseB   monoManual
# 4       06074fe2159d   warehouseA   monoManual
# ...              ...          ...          ...
# 121573  f931cc63aa25   warehouseB   monoManual
# 121574  fd3d162c659a   warehouseB   monoManual
# 121575  fe5c14b218f3   warehouseB   monoManual
# 121576  fefdccbd189c   warehouseB   monoManual
# 121577  fefdccbd189c   warehouseB   monoManual
#
#                                                  products  warehouse_costs  \
# 0                                       [83ee1b0d14e148a]              0.5
# 1                                       [4f14c89b683a428]              0.7
# 2       [650c3ad888a74f3, 30b1fbefd5ca45a, 9e571016c83...              4.2
# 3                                       [e758471031f34c2]              0.5
# 4                                       [5d4331c419a24ca]              0.7
# ...                                                   ...              ...
# 121573                                  [c669715883a9442]              0.5
# 121574                                  [64a912c7dff64bf]              0.5
# 121575                                  [3ef8dc897dfc4d2]              0.5
# 121576                                  [572aff5625d9420]              0.5
# 121577                                  [86cf47783e0342b]              0.5
#
#         shipment_costs             order_datetime  total_costs  quantity
# 0                  6.0 2021-01-01 18:50:36.719824          6.5         1
# 1                  5.0 2021-01-01 18:57:30.679387          5.7         1
# 2                  6.0 2021-01-01 18:57:30.679387         10.2         6
# 3                  6.0 2021-01-01 16:59:23.342815          6.5         1
# 4                  5.0 2021-01-01 22:35:34.041543          5.7         1
# ...                ...                        ...          ...       ...
# 121573             6.0 2021-12-30 15:47:19.274943          6.5         1
# 121574             6.0 2021-12-30 12:23:37.006524          6.5         1
# 121575             6.0 2021-12-30 15:45:00.543150          6.5         1
# 121576             6.0 2021-12-30 20:45:04.570772          6.5         1
# 121577             6.0 2021-12-30 20:45:04.570772          6.5         1
#
# [121578 rows x 9 columns]

# %%
simulation_result.lost_sales
# Out:
#      shop_order_id             order_datetime       product_id
# 0     e9588ae54f44 2021-01-05 16:17:04.976736  ef572fc53e1244f
# 1     eaaa7b535429 2021-01-05 18:33:25.703158  ad525ae3fac74e1
# 2     eb3031b98a19 2021-01-05 16:28:14.456537  4ffe48858f76491
# 3     ede3f7b81ad0 2021-01-05 14:11:48.085574  96f5fa1cd4ff4c7
# 4     ee69af0dd5b8 2021-01-05 21:03:14.508272  168896acf23149f
# ...            ...                        ...              ...
# 8901  f931cc63aa25 2021-12-30 15:47:19.274943  62e3040b6322463
# 8902  fa0858a42cba 2021-12-30 20:54:44.372585  810c38c9a7e94fe
# 8903  fc4a4217c8d0 2021-12-30 14:22:56.930373  b7236e8db94e4a8
# 8904  fda72877f233 2021-12-30 11:00:19.365373  0b64c0ea4f68450
# 8905  ffacf2dd74b7 2021-12-30 17:17:55.072247  5446e83ac9014db
#
# [8906 rows x 3 columns]

# %% [markdown]
# # Base model

# %%
#Initialize an empty list to store rows
warehouse_rows = []

# Iterate over rows in product_df and populate the warehouse_df based on conditions
for index, row in assortment_df.iterrows():
    product_id = row['product_id']
    cluster = row['cluster']

    # Initialize warehouseA and warehouseB as False
    warehouseA = False
    warehouseB = False

    # Check conditions and update warehouse columns
    if cluster in ['toy', 'garden', 'winter']:
        warehouseA = True
    elif cluster in ['clothes']:
        warehouseB = True

    # Append a new row to the list
    warehouse_rows.append({'product_id': product_id, 'warehouseA': warehouseA, 'warehouseB': warehouseB})

# Create a DataFrame from the list of rows
warehouse_df = pd.DataFrame(warehouse_rows)

# Display the resulting warehouse_df
warehouse_df
# Out:
#           product_id  warehouseA  warehouseB
# 0    007e97352fdb433       False       False
# 1    32b8b71245fc430       False       False
# 2    d6825ec8a7d5409       False       False
# 3    93210367755d441       False       False
# 4    1302c851692140a       False       False
# ..               ...         ...         ...
# 995  fd27949fe39645c        True       False
# 996  52047e1f1e96465        True       False
# 997  8028747200e8443        True       False
# 998  e1bac8e0a574429        True       False
# 999  1567ac8f26e34bd        True       False
#
# [1000 rows x 3 columns]

# %%
warehouse_df.describe()
# Out:
#              product_id warehouseA warehouseB
# count              1000       1000       1000
# unique             1000          2          2
# top     007e97352fdb433      False      False
# freq                  1        500        600

# %%
simulation_result = simulate(orders_df, warehouse_df)
simulation_result.show_aggregated_results()
# Out:
# Warehouse orders sourced: 92311
# Total costs: 1270093.1
# Lost sales: 67608 products

# %%
assortment_df.groupby("cluster").size()
# Out:
# cluster
# clothes    400
# garden     250
# toys       100
# winter     250
# dtype: int64

# %%
warehouse_df.groupby("warehouseB").size()
# Out:
# warehouseB
# False    600
# True     400
# dtype: int64

# %% [markdown]
# # total sales of the items

# %%
# Merge the DataFrames on the 'product_id' column
merged_df = pd.merge(orders_df, assortment_df, on='product_id', how='left')

# Calculate total sales for each product_id
total_sales_df = merged_df['product_id'].value_counts().reset_index()
total_sales_df.columns = ['product_id', 'total_sales']

# Sort the DataFrame by total sales in descending order
total_sales_df = total_sales_df.sort_values(by='total_sales', ascending=False)

# Display the resulting DataFrame with total sales sorted
total_sales_df
# Out:
#           product_id  total_sales
# 0    03b755d783fd4ec          644
# 1    62e3040b6322463          639
# 2    6b91277c742e439          634
# 3    36103fff52e640a          630
# 4    93210367755d441          627
# ..               ...          ...
# 995  0f44a9e6585b450           72
# 996  55a3f2db0b8846a           71
# 997  f98dbfdfecb7464           67
# 998  6e4120fb6f16405           65
# 999  0a7cf8ec13ba475           64
#
# [1000 rows x 2 columns]

# %%
#Initialize an empty list to store rows
warehouse_rows = []

# Iterate over rows in product_df and populate the warehouse_df based on conditions
for index, row in total_sales_df.iterrows():
    product_id = row['product_id']
    total_sales = row['total_sales']

    # Initialize warehouseA and warehouseB as False
    warehouseA = False
    warehouseB = False

    # Check conditions and update warehouse columns
    if (total_sales < 193) or (total_sales > 282):
        warehouseB = True
    if total_sales >= 142:
        warehouseA = True

    # Append a new row to the list
    warehouse_rows.append({'product_id': product_id, 'warehouseA': warehouseA, 'warehouseB': warehouseB, 'total_sales})

# Create a DataFrame from the list of rows
warehouse_df = pd.DataFrame(warehouse_rows)

# Display the resulting warehouse_df
warehouse_df
# Out:
#           product_id  warehouseA  warehouseB  total_sales
# 0    03b755d783fd4ec       False        True          644
# 1    62e3040b6322463       False        True          639
# 2    6b91277c742e439       False        True          634
# 3    36103fff52e640a       False        True          630
# 4    93210367755d441       False        True          627
# ..               ...         ...         ...          ...
# 995  0f44a9e6585b450       False        True           72
# 996  55a3f2db0b8846a       False        True           71
# 997  f98dbfdfecb7464       False        True           67
# 998  6e4120fb6f16405       False        True           65
# 999  0a7cf8ec13ba475       False        True           64
#
# [1000 rows x 4 columns]

# %%
percentiles_df = total_sales_df['total_sales'].quantile([0.2,0.4, 0.5,0.6, 0.75,0.8,0.90, 1]).reset_index(name='percentile')

# %%
percentiles_df
# Out:
#    index  percentile
# 0   0.20        97.0
# 1   0.40       142.4
# 2   0.50       193.0
# 3   0.60       202.0
# 4   0.75       217.0
# 5   0.80       222.0
# 6   0.90       281.5
# 7   1.00       644.0

# %%
warehouse_df.describe()
# Out:
#        total_sales
# count  1000.000000
# mean    200.679000
# std     140.180857
# min      64.000000
# 25%      99.000000
# 50%     193.000000
# 75%     217.000000
# max     644.000000

# %%
simulation_result = simulate(orders_df, warehouse_df)
simulation_result.show_aggregated_results()
# Out:
# Warehouse orders sourced: 128140
# Total costs: 909162.0
# Lost sales: 5825 products

# %%
both_true_df = warehouse_df[(warehouse_df['warehouseA'] == True) & (warehouse_df['warehouseB'] == True)]

# Display the resulting DataFrame
both_true_df
# Out:
# Empty DataFrame
# Columns: [product_id, warehouseA, warehouseB, total_sales]
# Index: []

# %%
warehouse_df.groupby("warehouseB").count()
# Out:
#             product_id  warehouseA  total_sales
# warehouseB
# False              403         403          403
# True               597         597          597

# %%
warehouse_df.groupby("warehouseA").count()
# Out:
#             product_id  warehouseB  total_sales
# warehouseA
# False              400         400          400
# True               600         600          600

# %%
#b ye tek tercih edilen ve çok satan ürünleri ekleyelim
# a'nın kapasite düşük olduğu için orta segment ürünler

# %%
simulation_result.warehouse_orders.head(30)
# Out:
#    shop_order_id warehouse_id    pack_line  \
# 0   00330b8e0df6   warehouseA   monoManual
# 1   0349de8a0eb0   warehouseB  multiManual
# 2   0349de8a0eb0   warehouseA  multiManual
# 3   051f784d56df   warehouseA   monoManual
# 4   06074fe2159d   warehouseA   monoManual
# 5   066c8ad52448   warehouseB  multiManual
# 6   06834e141123   warehouseA   monoManual
# 7   06c4433ccd33   warehouseA   monoManual
# 8   07c6b2840ec5   warehouseA   monoManual
# 9   082824e3f286   warehouseA  multiManual
# 10  097fa71aaf91   warehouseA  multiManual
# 11  0a6ea43ccd4b   warehouseA  multiManual
# 12  0a7c0d1f0603   warehouseA  multiManual
# 13  0c95e5f0af83   warehouseB   monoManual
# 14  0d382a6db37d   warehouseA   monoManual
# 15  0ef697114489   warehouseB  multiManual
# 16  0ef697114489   warehouseA  multiManual
# 17  0f2937b57a54   warehouseA   monoManual
# 18  0f81cfcfd1de   warehouseA  multiManual
# 19  1129ee7c5c74   warehouseA  multiManual
# 20  11e03e4024c5   warehouseA   monoManual
# 21  14e27482521f   warehouseA   monoManual
# 22  153db21056f5   warehouseA   monoManual
# 23  1549d3126969   warehouseA  multiManual
# 24  15a8c09f696f   warehouseA  multiManual
# 25  1c691aec809f   warehouseA   monoManual
# 26  1e7f3244cef5   warehouseA   monoManual
# 27  2296f35be2f3   warehouseB   monoManual
# 28  22aaefdaa7c4   warehouseA  multiManual
# 29  23a901c28274   warehouseB  multiManual
#
#                                              products  warehouse_costs  \
# 0                                   [83ee1b0d14e148a]              0.7
# 1   [9e571016c83f48c, 4f14c89b683a428, 30b1fbefd5c...              2.1
# 2   [589a31255ac5410, 650c3ad888a74f3, 26245953b65...              3.6
# 3                                   [e758471031f34c2]              0.7
# 4                                   [5d4331c419a24ca]              0.7
# 5                  [d241172391ce452, 1b38df5f1cbb4d4]              1.4
# 6                                   [379f3ea122b5457]              0.7
# 7                                   [3f92763d6f27426]              0.7
# 8                                   [55462138ca5d4b6]              0.7
# 9   [7d59758138f54bc, 5446e83ac9014db, 89038c7c240...              2.7
# 10  [29a8a6823b2441b, c93345348dd4411, 698d33ae255...              3.6
# 11                 [695197b032ed4ac, 9c7c3149f28e429]              1.8
# 12  [1140d12b56eb4cd, a9de28d0ff64497, 08a5f5ddce3...              2.7
# 13                                  [a43a018ff7264e3]              0.5
# 14                                  [92d87e7491a442d]              0.7
# 15  [8e5a318c8fa84d4, a9857d6ff6f0403, 6b3addfb47f...              2.1
# 16  [9d1c5def248d43d, f65f597e37e944e, 848fd46c09b...              3.6
# 17                                  [f718c5b250b841e]              0.7
# 18  [e689587e240b472, 666fa0b71a26411, d05bd1d82b8...              2.7
# 19                 [b3363f643dfd43b, 64e09b501acf425]              1.8
# 20                                  [3a6a4e1049d742d]              0.7
# 21                                  [f6915abf8b92471]              0.7
# 22                                  [791e21963e774dd]              0.7
# 23  [43993da173424a7, c2567f1e8b0c4bd, d8ae30f803c...              2.7
# 24                 [908236ba57a14c2, 1617fbb04470474]              1.8
# 25                                  [6e72a5447b274ef]              0.7
# 26                                  [567203a1f786449]              0.7
# 27                                  [69af14bd63e8483]              0.5
# 28                 [6ac0f167f278418, 58ad5a64eec3468]              1.8
# 29                 [337e69e94ebb400, 6b91277c742e439]              1.4
#
#     shipment_costs             order_datetime  total_costs  quantity
# 0              5.0 2021-01-01 18:50:36.719824          5.7         1
# 1              6.0 2021-01-01 18:57:30.679387          8.1         3
# 2              5.0 2021-01-01 18:57:30.679387          8.6         4
# 3              5.0 2021-01-01 16:59:23.342815          5.7         1
# 4              5.0 2021-01-01 22:35:34.041543          5.7         1
# 5              6.0 2021-01-01 22:40:29.796308          7.4         2
# 6              5.0 2021-01-01 21:42:41.512068          5.7         1
# 7              5.0 2021-01-01 19:59:16.647936          5.7         1
# 8              5.0 2021-01-01 14:07:08.932730          5.7         1
# 9              5.0 2021-01-01 17:05:27.890598          7.7         3
# 10             5.0 2021-01-01 13:42:55.374849          8.6         4
# 11             5.0 2021-01-01 13:01:27.573930          6.8         2
# 12             5.0 2021-01-01 14:50:48.998042          7.7         3
# 13             6.0 2021-01-01 15:37:23.829919          6.5         1
# 14             5.0 2021-01-01 08:11:52.414074          5.7         1
# 15             6.0 2021-01-01 09:06:06.987214          8.1         3
# 16             5.0 2021-01-01 09:06:06.987214          8.6         4
# 17             5.0 2021-01-01 20:05:27.066702          5.7         1
# 18             5.0 2021-01-01 06:46:13.962167          7.7         3
# 19             5.0 2021-01-01 16:34:07.498313          6.8         2
# 20             5.0 2021-01-01 18:20:44.655629          5.7         1
# 21             5.0 2021-01-01 17:26:26.431143          5.7         1
# 22             5.0 2021-01-01 09:38:12.234309          5.7         1
# 23             5.0 2021-01-01 13:23:05.060920          7.7         3
# 24             5.0 2021-01-01 13:35:46.894106          6.8         2
# 25             5.0 2021-01-01 13:51:04.625130          5.7         1
# 26             5.0 2021-01-01 19:21:58.094452          5.7         1
# 27             6.0 2021-01-01 10:22:20.437804          6.5         1
# 28             5.0 2021-01-01 22:29:14.315148          6.8         2
# 29             6.0 2021-01-01 12:27:56.831523          7.4         2
